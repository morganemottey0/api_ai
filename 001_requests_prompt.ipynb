# %%
# %%
# !pip3 install anthropic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting anthropic
#   Downloading anthropic-0.89.0-py3-none-any.whl (478 kB)
#      |████████████████████████████████| 478 kB 3.4 MB/s eta 0:00:01
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.13.0-cp39-cp39-macosx_11_0_arm64.whl (309 kB)
#      |████████████████████████████████| 309 kB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/morgane/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.15.0)
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 33.8 MB/s eta 0:00:01
# Collecting docstring-parser<1,>=0.15
#   Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 25.4 MB/s eta 0:00:01
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting httpx<1,>=0.25.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 8.5 MB/s  eta 0:00:01
# Collecting idna>=2.8
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 25.4 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/morgane/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 13.7 MB/s eta 0:00:01
# Collecting certifi
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 24.5 MB/s eta 0:00:01
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 9.9 MB/s eta 0:00:01
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: idna, h11, certifi, typing-inspection, pydantic-core, httpcore, anyio, annotated-types, sniffio, pydantic, jiter, httpx, docstring-parser, distro, anthropic
# Successfully installed annotated-types-0.7.0 anthropic-0.89.0 anyio-4.12.1 certifi-2026.2.25 distro-1.9.0 docstring-parser-0.17.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jiter-0.13.0 pydantic-2.12.5 pydantic-core-2.41.5 sniffio-1.3.1 typing-inspection-0.4.2
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# %%
# Cellule 1 — Imports et setup
import anthropic

client = anthropic.Anthropic(api_key="API_KEY")
messages = []

# %%
# %%
# Cellule 2 — Fonctions
def add_user_message(messages, user_input):
    messages.append({"role": "user", "content": user_input})

def add_assistant_message(messages, response):
    messages.append({"role": "assistant", "content": response})

def chat(messages):
    response = client.messages.create(
        model="claude-opus-4-5",
        max_tokens=1024,
        messages=messages
    )
    return response.content[0].text

# %%
# %%
# Cellule 3 — Boucle chatbot
while True:
    user_input = input("You: ")
    if user_input.lower() == "quit":
        break
    
    add_user_message(messages, user_input)
    response = chat(messages)
    add_assistant_message(messages, response)
    
    print(f"Claude: {response}\n")
# Out:
# Claude: The answer to 1 + 1 is **2**.
